# %%
import pandas as pd

#untuk dapat melihat seluruh kolom dan baris
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Read TransJakarta Transaction Data
#
# source: https://www.kaggle.com/datasets/dikisahkan/transjakarta-transportation-transaction

# %%
df= pd.read_csv("/content/drive/MyDrive/GreatEdu/DataFrame 1/dfTransjakarta.csv")

# %%
#check dimensi data
df.shape
#len(df)
# Out:
# (37900, 22)

# %%
#tampilkan top 5 data
df.head(5)
# Out:
#           transID         payCardID payCardBank      payCardName payCardSex  \
# 0  EIIW227B8L34VB   180062659848800      emoney   Bajragin Usada          M
# 1  LGXO740D2N47GZ  4885331907664776         dki     Gandi Widodo          F
# 2  DJWR385V2U57TO  4996225095064169         dki    Emong Wastuti          F
# 3  JTUZ800U7C86EH      639099174703       flazz     Surya Wacana          F
# 4  VMLO535V7F95NJ      570928206772       flazz  Embuh Mardhiyah          M
#
#    payCardBirthDate corridorID                              corridorName  \
# 0              2008          5                     Matraman Baru - Ancol
# 1              1997         6C  Stasiun Tebet - Karet via Patra Kuningan
# 2              1992        R1A                        Pantai Maju - Kota
# 3              1978        11D       Pulo Gebang - Pulo Gadung 2 via PIK
# 4              1982         12                     Tanjung Priok - Pluit
#
#    direction tapInStops          tapInStopsName  tapInStopsLat  tapInStopsLon  \
# 0        1.0     P00142               Pal Putih      -6.184631      106.84402
# 1        0.0    B01963P              Kemenkes 2      -6.228700      106.83302
# 2        0.0    B00499P            Gg. Kunir II      -6.133132      106.81435
# 3        0.0    B05587P            Taman Elok 1      -6.195743      106.93526
# 4        0.0     P00239  Sunter Boulevard Barat      -6.149650      106.88900
#
#    stopStartSeq            tapInTime tapOutStops        tapOutStopsName  \
# 0             7  2023-04-03 05:21:44      P00253                Tegalan
# 1            13  2023-04-03 05:42:44     B03307P    Sampoerna Strategic
# 2            38  2023-04-03 05:59:06     B04962P  Simpang Kunir Kemukus
# 3            23  2023-04-03 05:44:51     B03090P      Raya Penggilingan
# 4             5  2023-04-03 06:17:35      P00098       Kali Besar Barat
#
#    tapOutStopsLat  tapOutStopsLon  stopEndSeq           tapOutTime  payAmount
# 0       -6.203101       106.85715        12.0  2023-04-03 06:00:53     3500.0
# 1       -6.217152       106.81892        21.0  2023-04-03 06:40:01     3500.0
# 2       -6.133731       106.81475        39.0  2023-04-03 06:50:55     3500.0
# 3       -6.183068       106.93194        29.0  2023-04-03 06:28:16     3500.0
# 4       -6.135355       106.81143        15.0  2023-04-03 06:57:03     3500.0

# %%
#tampilkan data secara random
df.sample(5)
# Out:
#               transID        payCardID payCardBank             payCardName  \
# 37087  ZFZT036X3V63YB    4844470388320      online     Rina Gunarto, S.Sos
# 34574  WJIZ760V3K83OB     630480849201       flazz  Cut Tira Zulaika, M.Ak
# 14192  GSUU008N6G05DM  346754681244542      emoney        Maryadi Haryanto
# 22629  HJSM184D8X64HW     639083950241       flazz         H. Hadi Susanti
# 24249  BYJV669T3V60WU   30310358800206         bni        Legawa Oktaviani
#
#       payCardSex  payCardBirthDate corridorID  \
# 37087          M              1984    JAK.48A
# 34574          M              1991     JAK.50
# 14192          M              1968     JAK.03
# 22629          F              1992        10B
# 24249          F              1985        B14
#
#                                           corridorName  direction tapInStops  \
# 37087              Stasiun Tebet - Rusun Karet Tengsin        0.0        NaN
# 34574                       Kalideres - Puri Kembangan        0.0    B05652P
# 14192                             Lebak Bulus - Andara        0.0    B01085P
# 22629  Rusun Cipinang Besar Selatan - Penas Kalimalang        1.0    B02723P
# 24249                          Bekasi Barat - Kuningan        1.0    B00274P
#
#             tapInStopsName  tapInStopsLat  tapInStopsLon  stopStartSeq  \
# 37087        Mega Kuningan      -6.224556      106.82677            10
# 34574  Taman Semanan Indah      -6.163993      106.72545            32
# 14192         Jln. Grafika      -6.290158      106.77095             1
# 22629   Penas Kalimalang 2      -6.239095      106.87826             0
# 24249    Cipta Rasuna Said      -6.216146      106.83087             3
#
#                  tapInTime tapOutStops              tapOutStopsName  \
# 37087  2023-04-18 17:50:34     B01833P            Karet Pedurenan 1
# 34574  2023-04-30 08:21:48     B02001P    Klinik Andhika Rawa Buaya
# 14192  2023-04-05 07:48:44     B00684P  Graha Werdatama Pondok Labu
# 22629  2023-04-17 20:22:52     B05535P              STMT Trisakti 1
# 24249  2023-04-19 07:03:52     B00596P               Gedung Granadi
#
#        tapOutStopsLat  tapOutStopsLon  stopEndSeq           tapOutTime  \
# 37087       -6.221933       106.82093        12.0  2023-04-18 19:28:00
# 34574       -6.169275       106.73411        47.0  2023-04-30 08:45:44
# 14192       -6.309163       106.79461        20.0  2023-04-05 08:27:57
# 22629       -6.231933       106.87782         4.0  2023-04-17 21:43:21
# 24249       -6.231311       106.83301        10.0  2023-04-19 07:28:14
#
#        payAmount
# 37087        NaN
# 34574        0.0
# 14192        0.0
# 22629        0.0
# 24249    20000.0

# %% [markdown]
# #SORTING DATAFRAME

# %% [markdown]
# ## sort_values()

# %%
#urutkan berdasarkan salah satu kolom
df.sort_values('payCardBirthDate').head()

df.sort_values(by=['payCardBirthDate']).head()

# %%
#urutkan berdasarkan salah satu kolom, descending
df.sort_values('payCardBirthDate', ascending=False).head()

# %%
#sorting dengan mengabaikan index
df.sort_values(by='payCardBirthDate',ascending=False, ignore_index=True).head()

# %%
#perintah sort_values default tidak mengganti data awal
df.head()

# %%
#sorting dengan mengganti dataframe
df.sort_values('payCardBirthDate', inplace=True)
df.head()

# %%
#sorting dengan banyak kolom
df.sort_values(by=['payCardBirthDate','payCardName']).head()

# %%
#sorting dengan banyak kolom dengan urutan berbeda
df.sort_values(by=['payCardBirthDate','payCardName'],
               ascending=[True, False]).head()

# %%
#menampilkan data kosong terlebih dahulu
df.sort_values('corridorID',na_position='first').head()

# %% [markdown]
# ## sort_index()

# %%
#mengurutkan nama kolom
df.sort_index(axis=1).head(5)

# %%
#menyimpan hasil sorting ke dataframe baru
sorted_df = df.sort_values('payCardBirthDate')
sorted_df.head()

# %%
#menampilkan data sesuai index awal
sorted_df.sort_index().head()

# %%
#sort index pada multilevel dataframe
l = [[1,'A',99],[1,'B',102],[1,'C',105],[1,'D',97],[2,'A',19],[2,'B',14],[2,'C',10],[2,'D',17]]
df_multi = pd.DataFrame(l,columns = ['idx1','idx2','col1'])
df_multi.set_index(['idx1','idx2'],inplace=True)
df_multi

# %%
 df_multi.sort_index(level='idx2', ascending=False)

# %% [markdown]
# # FILTERING DATAFRAME

# %%
df.sort_index(inplace=True)
df.head()

# %% [markdown]
# ## Filtering dengan posisi

# %%
#menampilkan data berdasarkan index
df.loc[27]

# %%
#menampilkan data berdasarkan index dan kolom
df.loc[27, 'payCardName']

# %%
#mengganti kolom index
df_trans = df.set_index('transID')
df_trans.head()

# %%
#menampilkan data berdasarkan index
df_trans.loc["DJWR385V2U57TO"]

# %%
#filter 1 kolom
df_trans['payCardName'].head()

# %%
#filter multiple kolom
df_trans[['payCardName','payCardID']].head()

# %%
#iloc : filter 1 row
# df.iloc[5]
df.iloc[0, :] # tanda : melambangkan seluruh kolom/baris

# %%
#iloc : Memilih Sel Berdasarkan Baris dan Kolom
df.iloc[0, 5]

# %%
#iloc : Memilih sebagian Baris dan Kolom
df.iloc[3:9, 4:8]

# %%
#iloc : Memilih index negatif
df.iloc[-1] #data terakhir

# %% [markdown]
# ## Filtering dengan kondisi

# %%
#filter dengan kondisi
print(len(df))
df_female = df[df['payCardSex']=='F']
# df_female = df[~(df['payCardSex']=='M')]
print(len(df_female))
df_female.head()

# %%
#filter dengan banyak kondisi : dan
print(len(df))
df_female_dki = df[(df['payCardSex']=='F') & (df['payCardBank']=='dki')]
print(len(df_female_dki))
df_female_dki.head()

# %%
#filter dengan banyak kondisi : atau
print(len(df))
df_filtered = df[(df['payCardBank']=='flazz') | (df['payCardBank']=='dki')]
print(len(df_filtered))
df_filtered.head()

# %%
#filter dengan kondisi berada dalam list
print(len(df))
df_filtered = df[df['payCardBank'].isin(['dki','flazz'])]
print(len(df_filtered))
df_filtered.head()

# %% [markdown]
# ## Filtering dengan query

# %%
#filter dengan 1 kondisi
print(len(df))
df_filtered = df.query('payCardBirthDate > 2000')
print(len(df_filtered))
df_filtered.head()

# %%
#filter dengan banyak kondisi
print(len(df))
df_filtered = df.query('payCardBirthDate > 2000 and payCardSex=="M"')
print(len(df_filtered))
df_filtered.head()

# %% [markdown]
# # ADD COLUMS

# %%
#melakukan copy dataframe
df_add =df.copy()

# %%
# Menambahkan kolom baru dengan nilai tetap
df_add['negara'] = 'Indonesia'
df_add.sample(5)

# %%
#Menambahkan Kolom Berdasarkan Operasi pada Kolom Lain
df_add['payAmountDiscount'] = df_add['payAmount']*0.9
df_add.sample(5)

# %%
#Menambahkan Kolom Berdasarkan Kondisi
df_add['ageCategory'] = ['Dewasa' if tahunLahir <= 2007 else 'Muda' for tahunLahir in df['payCardBirthDate']]
df_add.sample(5)
